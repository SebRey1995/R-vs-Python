# %%
import pandas as pd
from dateutil.parser import parse
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/temixco.csv',index_col=0,parse_dates=True)
df.head(3)
# Out:
#                         Ib   Ig     To     RH     WS     WD         P
# time
# 2018-01-01 00:00:00    NaN  NaN  18.70  36.34  1.422  316.0  87864.11
# 2018-01-01 00:10:00  0.002  0.0  18.95  35.29  1.008  283.7  87876.37
# 2018-01-01 00:20:00  0.170  0.0  18.94  35.43  1.565  326.0  87888.64

# %%
df.resample('D').agg(['mean','max','std'])
# Out:
#                     Ib                             Ig                     \
#                   mean    max         std        mean    max         std
# time
# 2018-01-01  221.831692  745.9  292.146624  196.896224  753.0  274.827111
# 2018-01-02  249.390757  803.0  312.282169  207.372653  774.8  285.234929
# 2018-01-03  218.034125  747.1  293.158583  201.641069  757.7  280.802930
# 2018-01-04  225.306146  718.4  290.492676  204.159410  761.1  282.284366
# 2018-01-05  218.640007  754.2  293.676947  201.917583  762.4  281.820180
# ...                ...    ...         ...         ...    ...         ...
# 2018-12-27  231.563910  911.0  321.704459  196.115382  982.0  274.080060
# 2018-12-28  171.924813  756.6  236.097794  187.943847  802.0  256.896885
# 2018-12-29  340.988951  946.0  405.619586  221.332215  799.6  299.339033
# 2018-12-30  256.269431  899.0  357.891344  202.694910  795.8  292.782125
# 2018-12-31  256.769687  912.0  349.341581  202.179840  902.0  285.729880
#
# ...
